# %%
import numpy as np
import pandas as pd
from scipy.stats import stats
import matplotlib.pyplot as plt
import statsmodels.api as sm
from scipy.stats import levene,shapiro,f_oneway
# %matplotlib inline

# %%
a=pd.read_csv('CardioGoodFitness.csv')

# %%
a.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
a.describe()
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
# Product          180 non-null object
# Age              180 non-null int64
# Gender           180 non-null object
# Education        180 non-null int64
# MaritalStatus    180 non-null object
# Usage            180 non-null int64
# Fitness          180 non-null int64
# Income           180 non-null int64
# Miles            180 non-null int64
# dtypes: int64(6), object(3)
# memory usage: 12.7+ KB

# %%
a.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001F056396F28>,
# ...
#       dtype=object)

# %%
import seaborn as sns

# %%
sns.boxplot(x='Gender',y='Age',data=a)

# %%
VF=pd.crosstab(a['Gender'],a["Product"]).T

# %%
sns.boxplot(x='Gender',y='Miles',hue='MaritalStatus',data=a)

# %%
import scipy.stats as stats
import

# %%
table2= np.array(VF)
table2
# Out:
# array([[40, 40],
#        [29, 31],
#        [ 7, 33]], dtype=int64)

# %%
from scipy.stats import chisquare,chi2_contingency
table3 = chi2_contingency(table2)
table3
# Out:
# (12.923836032388664,
#  0.0015617972833158714,
#  2,
#  array([[33.77777778, 46.22222222],
#         [25.33333333, 34.66666667],
#         [16.88888889, 23.11111111]]))

# %%
x = ((table2-table3[3])**2)/table3[3]
x
# Out:
# array([[1.14619883, 0.83760684],
#        [0.53070175, 0.38782051],
#        [5.79020468, 4.23130342]])

# %%
sns.boxplot(x='Product',y='Miles',data=a)

# %%
sns.boxplot(x='Product',y='Income',hue='Fitness',data=a)

# %%
pd.crosstab(a['Gender'],a['Fitness']).T
# Out:
# Gender   Female  Male
# Fitness
# 1             1     1
# 2            16    10
# 3            45    52
# 4             8    16
# 5             6    25

# %%
sns.pairplot(a)

# %%
a.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
a.cov()
# Out:
#                     Age     Education        Usage      Fitness        Income  \
# Age           48.212166      3.149410     0.113470     0.406828  5.884446e+04
# Education      3.149410      2.614867     0.693172     0.636623  1.670472e+04
# Usage          0.113470      0.693172     1.176785     0.695469  9.303043e+03
# Fitness        0.406828      0.636623     0.695469     0.919429  8.467925e+03
# Income     58844.463439  16704.717815  9303.042582  8467.925388  2.724706e+08
# Miles         13.186530     25.770795    42.709808    39.073246  4.652654e+05
#
#                    Miles
# Age            13.186530
# Education      25.770795
# Usage          42.709808
# Fitness        39.073246
# Income     465265.361887
# Miles        2689.833489

# %%
Pr
